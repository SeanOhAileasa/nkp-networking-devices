# %%
from IPython.core.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from sys import path; path.insert(1,"../src");
import fubar; from importlib import reload; reload(fubar);
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-networking-devices/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Networking Devices``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %%
# from sys import path; path.insert(1,"../src")
# from fubar import fFile

# %%
# %%script bash
# grep -1 "def fFile" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fFile(nParPath):
#     """Start a file with its associated application.
#
# Input: nParPath
# Process: (os.path.realpath; os.startfile)
# Output: file opened with associated application
# """
#     from os import path,startfile
#     return startfile(path.realpath(nParPath))
# # --- END ---

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Types of Networking Devices](#topTypesofNetworkingDevices)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topTypesofNetworkingDevicesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topTypesofNetworkingDevices"></a>
# ### [Types of Networking Devices](#typesofNetworkingDevices)
#
# * [1. Course Introduction](#typesofNetworkingDevices1CourseIntroduction) <br/><br/>
# * [2. Firewalls](#typesofNetworkingDevices2Firewalls) <br/><br/>
# * [3. Routers](#typesofNetworkingDevices3Routers) <br/><br/>
# * [4. Switches and Hubs](#typesofNetworkingDevices4SwitchesandHubs) <br/><br/>
# * [5. Bridges](#typesofNetworkingDevices5Bridges) <br/><br/>
# * [6. Modems](#typesofNetworkingDevices6Modems) <br/><br/>
# * [7. Wireless Routers and Access Points](#typesofNetworkingDevices7WirelessAccessPoints) <br/><br/>
# * [8. Media Converters](#typesofNetworkingDevices8MediaConverters) <br/><br/>
# * [9. Wireless Range Extenders](#typesofNetworkingDevices9WirelessRangeExtenders) <br/><br/>
# * [10. VoIP Endpoints](#typesofNetworkingDevices10VoIPEndpoints)

# %% [markdown]
# ### [Practice: Configure Network Devices](#practiceConfigureNetworkDevices)
#
# * [1. Exercise: Configure Network Devices](#exerciseConfigureNetworkDevices)

# %% [markdown]
# <a id="topTypesofNetworkingDevicesTest"></a>
# ### ⚡ [Test](#typesofNetworkingDevicesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices"></a>
# ***
# ### Types of Networking Devices
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices1CourseIntroduction"></a>
# ***
# ###### 1. Course Introduction
# ***

# %% [markdown]
# This course will cover various networking devices including Modems, Hubs, Switches, Bridges, and Routers and also discuss proxy servers, load balancers, VPN concentrators and intrusion detection and prevention systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices2Firewalls"></a>
# ***
# ###### 2. Firewalls
# ***

# %% [markdown]
# In this presentation, we'll introduce the basic functionality of a firewall, which is software or hardware used to control ingress and egress of network traffic and that refers to the direction. Traffic coming in and/or traffic coming out.

# %% [markdown]
# And you can control both of them with a firewall. And it is quite simply designed to prevent unauthorized access to a private network. Of course on the Internet, there could be intruders that are trying to gain access to proprietary information on the inside. The firewall in essence is designed to protect that information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Software-based Firewall
# ***

# %% [markdown]
# Now there are two main types, a software based firewall that runs on a host PC or server. And as such, it's called a host-based firewall.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Host-based Firewalls
# ***

# %% [markdown]
# And it really is just configurable software on that system. And in fact, in Windows environments, all recent Windows clients and servers included a firewall by default ever since Windows XP. And you can just configure it through the Control Panel.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network-based Firewalls
# ***

# %% [markdown]
# And then there's the network-based firewall. This is typically a dedicated device, although they might run on a server, and we'll actually come back to that in a moment.

# %% [markdown]
# But it typically segregates a LAN from devices on an untrusted network. And of course the untrusted network is the Internet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So the primary difference is that the network based firewall is designed really to protect the entire network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Filtering Techniques - Packet Filter
# ***

# %% [markdown]
# Now, some of the filtering techniques that are used in firewalls include a packet filter which accepts or rejects packets entering or leaving the network. And you can configure the criteria yourself with respect to what is allowed and what is not. So it quite literally examines the packets and if it meets the criteria, it is accepted. And if it does not meet the criteria, it is discarded.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Filtering Techniques - Application Gateway
# ***

# %% [markdown]
# An application gateway applies security mechanisms to specific applications. So it depends on the application you are using.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Filtering Techniques - Circuit-level Gateway
# ***

# %% [markdown]
# A circuit level gateway applies security mechanisms to TCP and/or UDP connections, so it works on the port numbers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Filtering Techniques - Proxy Server
# ***

# %% [markdown]
# And a proxy server hides the network addresses because it only ever exposes the public network to the Internet. So you don't ever see what kind of addresses are being used on the inside.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hardware-based Firewall
# ***

# %% [markdown]
# So then, comparing hardware and software firewalls. Again the hardware firewall is typically a dedicated device and in many cases it is also the router.

# %% [markdown]
# So it handles the connection between your network and the Internet. Recall that routers connect networks together. So in many cases the firewall is implemented on the router.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# They require at least two ports, two physical connections, that's referred to as dual-homed, in order to segregate inside traffic from outside traffic.

# %% [markdown]
# One port connects into the private network and one port connects out to the public Internet.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Software versuis Hardware-based Firewall
# ***

# %% [markdown]
# But the software firewall is installed on a single host. And in that regard, it is designed to only protect the host on which they are installed. So where a network firewall sits on the boundary and protects everything behind it, a software firewall is usually implemented as a second line of defense. So that when traffic arrives on that specific computer, it must still meet all of the firewall rules.

# %% [markdown]
# Now the distinction between hardware and software is a little bit blurred by network firewalls that are running on Windows or Linux hosts. We see a bit of a combination here. It is a host based firewall because it's running on a server. But you can place that server on the border of your network, and it can then perform the same task. So it's just a little bit of a crossover, if you will, there. It is a software firewall, but it is performing the job of a hardware firewall. So just it again just blurs that line a little bit. But its purpose is the same, to protect all of the systems behind the firewall.

# %% [markdown]
# Now one final distinction when it comes to securing the environment with a firewall, that sometimes is not always that clear. It is designed purely to protect from intrusion and attack. It does not do anything with respect to preventing viruses from entering the network or any kind of malware. They often come in just in the form of an attachment to an email. So a firewall does not protect against that. It is trying to keep the resources of your network protected by again implementing these various techniques. But it is designed for really just that purpose, not anti-malware or any kind of antivirus software.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices3Routers"></a>
# ***
# ###### 3. Routers
# ***

# %% [markdown]
# Now, in this presentation, we'll take a look at the basic characteristics of a router.

# %% [markdown]
# And recall from our OSI model that the third layer is the network layer and this is where we find routers. [Router.] Hence, they're often referred to as layer 3 devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### OSI - Network Layer
# ***

# %% [markdown]
# Now, at the network layer, the devices are not concerned with connecting any specific hosts to each other, just the networks. We also find the logical address at the third layer, in other words, the IP address, in most cases. So routers forward packets off to other networks based on the IP address of the networks that are being connected. But again, it does not concern itself with the host portion of the address. It only considers the network portion of the address, so that it can find the router for that network. And as soon as it forwards the packet off to that next router, it’s job is finished. So again, it's not concerned with finding a specific host on that network, just the way to get in to that network. So it's often referred to as a gateway device because it sits on the border or the boundary of your network. And it's our last point of contact as packets move out of the network. And it's the first point of contact for packets that are coming into our network.

# %% [markdown]
# So it always connects at least two networks together. And that can be a LAN to a WAN, a LAN to another LAN within your own organization, or of course, very commonly, your LAN to your Internet service provider.

# %% [markdown]
# Now, routers can contain processors, memory, and various input or output interfaces because they need to make decisions, if you will. There needs to be some programming in a router. They are effectively smarter than devices such as hubs, they don't make any decisions. But routers need to be programmed, so there has to be a processor, there needs to be memory. And the interfaces are how we configure the device. So it doesn't have its own keyboard or display. You connect to one of those I/O interfaces using your own computer, and you configure it remotely.

# %% [markdown]
# Typically, most higher level routers are just rack-mounted devices that, again, just don't have any kind of configuration capabilities inherently within the device itself. Maybe you might be able to reset it back to its factory default settings, that's about it. Almost every other configuration is done using a remote connection through one of those interfaces.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Types of Routers
# ***

# %% [markdown]
# Now, in terms of the types of routers available, there are several different classifications, if you will. And certainly these days, with the prevalence of home Internet and small offices, we have become very familiar with the broadband router.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Broadband Router
# ***

# %% [markdown]
# Now, this is used to connect both computers together and those computers to the Internet. So that seems to contradict what I just said about connecting computers together. But it really is a separate functionality built into the single device. So it is still just one piece of hardware. But it performs switching functions within it, and then it quite separately performs routing.

# %% [markdown]
# So sometimes you'll hear it referred to as a layer 3 switch. Switches operate at layer 2, and they connect computers together. But the fact that it is also capable of performing routing, which is the next layer up, is why you sometimes hear the layer 3 switch.

# %% [markdown]
# Again, they are completely separate functions just built into a single unit. So the switching portion is where you typically see maybe four or six ethernet ports on the device. So that the computers that are connected to it can talk to each other, but that's a separate functionality. Then once that has been accomplished, then that little network is then connected to your ISP. So again, it's just performs both tasks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless Router
# ***

# %% [markdown]
# A wireless router is really no different. It simply allows for wireless connections, so that you can increase the size of your LAN. Most of the home routers might only have four, maybe six physical ports, so you're quite limited in terms of the wired connections. But then you can really have any number of wireless that can also connect. And then that just increases the size of the LAN, but that is all still switching at its core.

# %% [markdown]
# So again, it performs the routing separately to be able to connect to your ISP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Other Routers
# ***

# %% [markdown]
# Now, other types of routers that you might see in larger environments include the edge router, the subscriber edge router, the inter-provider border router, and the core router. And you might hear some different terms here, but these are just classifications really.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Edge Router
# ***

# %% [markdown]
# The edge is typically what you will see on the edge of your ISP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Subscriber Edge Router
# ***

# %% [markdown]
# The subscriber edge would be the one that's implemented in my organization. So my subscriber edge router connects to the edge router of the ISP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Inter-provider Border Router
# ***

# %% [markdown]
# And then the inter-provider border router typically is ISP to ISP, really the core or the backbone of the Internet itself. So that all Internet service providers are able to route amongst each other.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Core Router
# ***

# %% [markdown]
# And then a core router is typically on the inside. They generally do not touch the public Internet. So larger environments that do need to have separated networks within the organization will use core routers to implement that separation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Router Placement
# ***

# %% [markdown]
# So this is a very basic example of what it looks like in terms of placement. But on the top, we see pretty much the most basic network.

# %% [markdown]
# Computer-1 and Computer-2 are connected together with a switch.

# %% [markdown]
# And we see the same thing on the bottom, Computer-3 and Computer-4 are connected with a switch.

# %% [markdown]
# So those switches are concerned with directly connecting the hosts together. But then, of course, the switch in both cases also connects to the router. But those are separate networks. In terms of IP addressing, the top network might be something like 192.168.0 for its network address. The bottom one would be 192.168.1. Those are different network addresses.

# %% [markdown]
# So the router is responsible for connecting those two networks together. And it doesn't matter how large those networks might grow. The router is only concerned with connecting the networks. So there would be an entry programmed in the router, to say that one interface connects to 192.168.1.0. The other one connects to 192.168.1. And it facilitates the connectivity between those networks so everyone can now see everyone. But since they are officially different networks, you have to route between them. You cannot just connect switch to switch if you are using different network addresses. Because switches don't see the distinction between the network address.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Depend on Configuration with repeat to Addressing
# ***

# %% [markdown]
# So ultimately, it depends on how you are configuring your environment with respect to the addressing. And always remember that routers operate at layer 3, the network layer. Therefore, they are only concerned with connecting networks together.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices4SwitchesandHubs"></a>
# ***
# ###### 4. Switches and Hubs
# ***

# %% [markdown]
# Now taking a closer look at some of the characteristics of the lower layer devices, if we go all the way to the physical layer, or Layer 1, [Hub.] we find the hub.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hub
# ***

# %% [markdown]
# Now this is used to connect hosts together or segments of a LAN.

# %% [markdown]
# And it contains multiple ports, and packets arriving at one port are copied to all other ports. So this does allow all segments to see those packets or all hosts to see those packets. But, of course, the problem is, at the physical layer there is no addressing whatsoever. So quite simply stated, hubs aren't particularly smart. They are not aware of any kind of address. Despite the fact that the MAC address is often referred to as a physical address, it resides at Layer 2. So because a hub is unaware of any kind of address, anything that comes in one port has to be copied out every other port. Because the hub has no way to distinguish which system is connected to any given ports. So it has to copy that information to every port. So quite simply, hubs are noisy. They did the job, but they caused a lot of unnecessary traffic. Now their attractive feature, going back several years, was quite simply the fact that they were less expensive than switches. But in today's networking environments, it would be very rare to find a hub.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Switch
# ***

# %% [markdown]
# So switches, quite simply, operate at the next layer up. They operate at the data link layer, and as such, they are aware of MAC addresses.

# %% [markdown]
# Recall, the data link layer is subdivided into the MAC sublayer and logical link control.

# %% [markdown]
# So now we start to see an address implemented. And because of that, we can increase the overall bandwidth of the environment simply by not flooding the network with a bunch of unnecessary traffic.

# %% [markdown]
# So switches are aware that computer one is connected to physical port one and computer two is connected to physical port two and so on.

# %% [markdown]
# As packets arrive from that system, it picks up on the MAC address that was used to send it and it records it, and it now knows that this system resides on that port. Now, you can end up with certain scenarios where you have multiple switches connected to each other. Whereby any given system is, at least temporarily, unable to find any other system, perhaps because those tables have been cleared or changed, or anything along those lines. So it is possible that you can get these looping scenarios. But that can be addressed and/or corrected through the use of VLANs and what's known as the Spanning Tree Protocol. And we'll talk about some of those configurations in greater detail in some upcoming presentations. But this, quite simply, prevents that looping from happening, or at least if it does happen, it detects it and is able to stop it from continually looping.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Switch Configuration
# ***

# %% [markdown]
# Now not only is a switch capable of filtering traffic based on MAC addresses, it also supports configuration which, again, is something that hubs do not support.

# %% [markdown]
# So common Ethernet switch port parameters include the interface speed, the duplex, and the auto mdix, which is media dependent interface crossover. Now we'll come back to that in the moment.

# %% [markdown]
# The speed is, quite simply, how fast can this physical port communicate with whatever is on the other end.

# %% [markdown]
# Now most switches these days, I might even go so far as to say all of them, would have an auto-sensing capability so that it can negotiate. But if you know that the device on the other end can only communicate, let's say, at a 100 megabits per second, maybe it's a little bit older, then you can statically set that and you reduce a little bit of processing. Because the auto-sensing does have to do a little bit of negotiation, if you will.

# %% [markdown]
# The same goes for the duplex, that's whether or not it can send and receive at the same time. So full duplex is the ability to do just that, but half duplex is send and receive separately. So you can configure that as well. And, again, there would be the auto-sensing capability. But, as mentioned, the less you have to auto-sense, the less processing you have to do. So static configuration typically is better but, of course, if something changes, you have to go back in and reconfigure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Switch Configuration - Auto MDIX (Media Dependent Interface Crossover)
# ***

# %% [markdown]
# Now the auto mdix, again, is that media dependent interface crossover, that deals with the wire configuration in terms of transmitting and receiving. For example, a regular Ethernet port uses the pins 1 and 2 to transmit and 3 and 6 to receive. So that is a function, then, of what type of physical cable you place between the two endpoints. So if it's a regular computer on one side, then the switch on the other, that's the standard straight-through cable and the pins are placed accordingly to communicate.

# %% [markdown]
# But if it's switch to switch, that is typically where you see the crossover cable, or the rollover cable depending on the circumstances, but they have different wire configurations. But, again, a lot of newer devices have this auto mdix capability, which means that it can digitally rework the connection, if you will, so that you can actually use a straight-through cable in a scenario where it expects to see a crossover or a rollover. So it quite literally reconfigures the wires digitally, if you will, before the communications are sent to the processor.

# %% [markdown]
# So it doesn't really matter how the physical wire is lined up, in that case. But, again, it is something that you can set statically or you can leave it set to this auto-sensing capability, so that it can determine it for itself.

# %% [markdown]
# Ultimately, the auto-sensing capability reduces the changes that need to be made, but it involves more processing. So you might be able to improve the overall performance of the switch by statically configuring these values, but that introduces a little more overhead if and/or when things change.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices5Bridges"></a>
# ***
# ###### 5. Bridges
# ***

# %% [markdown]
# Now, our next interconnection device is the bridge. [Bridge.]

# %% [markdown]
# Now, this also operates at layer 2, or the data link layer.

# %% [markdown]
# So right away, we know that it works on MAC addresses, the same as switches. [It operates at layer 2.] So it's still used to join two separate network segments together, which enables communication between those segments using the same protocol. And it can also be used to extend a network.

# %% [markdown]
# Well, that all said, how does this differ from implementing a router between those two segments? And/or even just relying on the inherent ability of switches to filter traffic based on MAC address.

# %% [markdown]
# Well, there are a few scenarios where they do differ, and we’ll come to those. But before that, I just want to stress the keyword of network segment here. When you are talking about using a bridge, you aren't connecting networks together like a router. Recall, the router works at the network layer. And as such, it would have to use different network addresses. [In the graphic, two sets of two computers are interconnected with a router and are connected to each other with a bridge.]

# %% [markdown]
# If it was a router, that would have to be something like 192.168.0 as the network address. And then the one on the right would have to be something like 192.168.1, different network addresses.

# %% [markdown]
# So a bridge operating at layer 2 does not know the difference between a network address and any other network address.

# %% [markdown]
# Therefore, the addressing scheme of this configuration still has to be all the same networks, such as 192.168.0. The segments are just the different portions on one side versus the other. So it performs the same type of functionality in terms of trying to keep the traffic separate on either side, but it still does so based on MAC addresses. So then you think, well, why not just use a switch, because a switch can do exactly that? It can filter based on MAC address, and it can. But bridges do have some additional functionality that switches don't.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So where you might see a bridge?

# %% [markdown]
# When you have dissimilar media or different network architectures.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### See a Bridge - Dissimilar Media
# ***

# %% [markdown]
# When you have dissimilar media or different network architectures.

# %% [markdown]
# So, for example, we might have unshielded twisted pair as the cabling on the left hand side and fiber optic on the right. This is where the bridge comes into play.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### See a Bridge - Architecture
# ***

# %% [markdown]
# Also the architecture. Now, it's very unlikely that you would see a token ring configuration these days. But it did have that ability to translate from Token Ring to Ethernet.

# %% [markdown]
# So again, switches were not able to do that. So even though it looks like a routing type of configuration, it's all still the same network address. But it had the ability to connect these dissimilar types of networks that switches aren't able to do.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bridge Types - Local Bridge
# ***

# %% [markdown]
# In terms of the types of bridges, there is a local bridge which directly connects LAN segments. So that's basically what you're seeing in the graphic here. [In the graphic, two sets of two computers are interconnected with a router and are connected to each other with a bridge.] And again, it's just used to try to quiet things down a little bit or to connect those dissimilar media types.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bridge Types - Remote Bridge
# ***

# %% [markdown]
# Then a remote bridge is used to create a WAN link between LANs. Certainly, still the same network address, but recall that you can have a network of just about any size. So it's still a WAN link, but one LAN is in, perhaps, one physical building, and another LAN is in a different physical building. But it can all still be the same network address by TCP/IP configuration, so it's still the same approach. We are just connecting them together but still all the same address.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bridge Types - Wireless Bridge
# ***

# %% [markdown]
# And you can also have the wireless bridge. This provides wireless connectivity from your Ethernet ports. So several devices can benefit if the bridge is connected to a hub or a switch. And again, it just gives you the ability to extend that segment to allow for more devices to connect wirelessly.

# %% [markdown]
# But ultimately, the bridging capability is still to just interconnect segment one with segment two. And allow those two segments to still communicate with each other when necessary, but to try to isolate most of the time. So that if most of the traffic within segment one is destined for other systems in segment one, it never passes that traffic over to segment two.

# %% [markdown]
# So it's still able to make that determination based on MAC tables in the bridge. So it still quiets things down, but it does it based on MAC address as opposed to IP address. But the entire network, in and of itself, still has to all be one network by its TCP/IP address. So that's the difference between bridging and routing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices6Modems"></a>
# ***
# ###### 6. Modems
# ***

# %% [markdown]
# Our next interconnectivity device is the modem.

# %% [markdown]
# Now, by today's standards, of course, the modem is virtually extinct. [Modem.] Although, in certain very rural areas, you may still see them used to connect to your Internet service provider, simply because they don't have the infrastructure in places so far out. But very rare by today's standards. It is short for modulator-demodulator and quite simply enables a computer to transmit data using a telephone line.

# %% [markdown]
# And of course, that was the key component back in the early days of Internet connectivity. We didn't have high-speed networks all over the globe. But we did have the phone line. It was already there, so the infrastructure was already in place. So we could simply take advantage of that to communicate. The standard interface was called an RS-232.

# %% [markdown]
# Now, clearly, the speeds that we need today were not supported by modems. The phone lines could only carry very small amounts of data. There was very slow bandwidth. Modems never got faster than 56.6 kilobits per second in terms of their speeds, so extraordinarily slow by today's standards. But they did the job at the time.

# %% [markdown]
# So they're used to convert digital and analog information. That's the modulate/demodulate component, because information transmitted over a phone line is sent using analog waves. And that simply means that the signal that is sent out uses digits, ones and zeros, to create a waveform analogous to the actual electrical current. That's where the term analog came from. It is analogous to the actual signal. So again, we are feeding ones and zeros into the modem. The modem has to modulate/demodulate those ones and zeros into electrical signals. So that's how the communication was facilitated, but again, it was, of course, very slow.

# %% [markdown]
# But it did have the advantage of global access pretty much right from the get go, because the phone lines were available just about globally.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Types of Modems
# ***

# %% [markdown]
# Now, there were two basic types, a hardware modem and a software modem. Now, there's a little bit of confusion sometimes with respect to these, because both of them are still hardware. The difference really came in when it came down to the processing.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Types of Modems - Hardware
# ***

# %% [markdown]
# So a hardware modem, such as a dial-up modem, can often communicate with things like fax machines as well. But it simply meant that all of the processing that happened within the modem actually occurred on the modem itself. So there was a processor. There was a little bit of memory. There was everything necessary to translate the communications and present the operating system with processed data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Types of Modems - Software
# ***

# %% [markdown]
# A software modem is a low-cost version of that, easy to upgrade and popular in laptops because they were smaller. There was just less hardware. Basically, it was nothing more than a means to get the signals into the computer. From that point, you relied on the computer's processor and memory and resources to process the data. So that's why it was called a software modem. It was configured using software within the operating system. And it relied on the operating system to handle the data. So it was a little more processing involved from the perspective of the computer. But it wasn't all that much, so they didn't really degrade your performance that much. And again, the attractive feature, they were lower cost.

# %% [markdown]
# So a software-based modem was typically cheaper and a little more attractive if you were looking to install them in a lot of laptops for your mobile workforce at the time. But again, these days, I think you'd be hard-pressed to find either. But they do still exist. And typically, they would be very inexpensive by today's standards, even if you did have to implement one. So I don't think you'd see a software modem implemented if you were still needing some kind of modem.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices7WirelessAccessPoints"></a>
# ***
# ###### 7. Wireless Routers and Access Points
# ***

# %% [markdown]
# Now in this presentation, we'll take a closer look at wireless routers and access points, which are special purpose communication devices for wireless LANs or WLANs. The access points are used to provide a hotspot for wireless clients in the vicinity. [Wireless Routers and Access Points.] And these days most people are fairly familiar with this, if you go to a hotel, for example, or an airport. These very large buildings that are too large for something like a home or a small office wireless router to handle. This is where you see the access points come into play. They extend the range so that you can move just about anywhere within the structure and still remain connected.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless Access Points
# ***

# %% [markdown]
# So they act as a bridge between the wired and the wireless networks. And you can see in the graphic here, the access points themselves are wired to the switch along with everything else that's wired to the switch. So they have that wired connection, then they simply accept the wireless devices and it can be just about anything. You see here again in the graphic, a laptop with a PC card reader, that might be an older one that does not have an integrated adapter, which of course newer laptops do. Mobile devices, even desktops with a PCI or a USB adapter can all connect. So it really depends on what you have and where they are located but they all have the ability to connect to the wireless.

# %% [markdown]
# Now the access point itself can be a multifunction device, in other words it could also be a switch for example, so I could wire other devices to the access point if necessary. But typically the single purpose device can be a little more efficient, in the other words it is only concerned with handling the wireless connections.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now they can be used to strengthen security, but that is a bit of a relative approach and I'll clarify that in a moment, but they certainly extend the wireless range of service. Again, the idea being that you want to be able to move anywhere without having to reconnect to a different device. The idea is that once you establish the connection, as long as you are in range of any access point, you will still remain connected. So, you don't see any of that. It might happen transparently in the background but again, in a very large building such as an airport for example. You can go just about anywhere and you remain connected.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security
# ***

# %% [markdown]
# Now coming back to the security, that is as mentioned, a little bit of a relative term to say that you can strengthen it.

# %% [markdown]
# If you consider a purely wired network then that in and of itself by nature would be more secure than a wireless, because you are now transmitting signals through the air. So of course, those signals can be picked up on by an intruder and they may be able to gain access. So it's not as secure in that regard. But if I am able to gain physical access to your environment, so if I'm an intruder, and I can get into your environment and access a physical data port. Then, there really is nothing preventing me from connecting to the network. I can just pull out my laptop, pull out a wire, and connect my system to your network. And, again, apart from the physical security that might be in place, there's nothing that then is stopping me from gathering up those packets and possibly collecting sensitive information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security - Security Set Identifier (SSID)
# ***

# %% [markdown]
# At least with a wireless access point, you need the security information. You need to know the SSID, which is the security set identifier which is the name of the network. Now that is typically broadcasted so people can see it but you can also hide it. We'll see that in a moment. That's not particularly secure but of course there's also encryption in place. You need to have the appropriate type of encryption, you need the appropriate credentials to be able to connect. So quite simply, there are barriers to entry with a wireless access point that might not be there in a physical environment. So again, it's a little bit of a relative comparison, but at least with the access point, you do have to supply that information. You have to know how to connect, whereas if I do gain physical access, nothing stops me from plugging into a data port.

# %% [markdown]
# So again, coming back to the SSID, this is typically broadcasted. Again, when you go to a hotel or to an airport, you see the name of the network so that you know which one to connect to. But for security reasons the SSID can be hidden from the general public. Now this is not a tremendous means of implementing security because there is a lot of software available that can just pick up on these signals. They're still there and can usually uncover the hidden SSID. But for the general public who aren't skilled intruders, they don't even see it. So they might be just pulling up their laptop and seeing what is available to connect to. If the SSID is hidden, they simply don't see it, so they wouldn't even know to try to connect to it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security - Rogue Access Points and Evil Twin
# ***

# %% [markdown]
# Rogue Access Points and Evil Twin

# %% [markdown]
# Now some other considerations when it does come to access points, the rogue access point and or the evil twin.

# %% [markdown]
# A rogue access point is quite simply an unauthorized access point that is connected to a company network. So it's basically an intruder who has gained physical access just sets up one that is entirely unauthorized, it's not supposed to be there. So it can provide attackers with access to the company LAN over Wi-Fi.

# %% [markdown]
# An evil twin is something that poses as a legitimate access point using the same name, for example, but just used to lure people into connecting to it. So these are known as phishing scams. The attacker sets up a legitimate looking access point, possibly using a portable hotspot and then harvests the data. So again, it looks legitimate but it certainly is not. You lull the users into establishing this connection and then of course, they start transmitting passwords and things like that over the connections, so the intruder is able to pick up on that in some cases.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Considerations
# ***

# %% [markdown]
# So again, those are just things to consider when it comes to implementing wireless, and there are environments that to this day simply will not implement wireless particularly because of very high security requirements. In those places they just won't take the chance of broadcasting information over wireless transmission. So it depends on the nature of the network and what it is that you need to do. But if security is not a tremendous concern and you are more concerned with functionality, then absolutely consider implementing wireless access points to extend the capabilities and the range of your wireless network environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices8MediaConverters"></a>
# ***
# ###### 8. Media Converters
# ***

# %% [markdown]
# In this presentation, we'll take a look at an example of a media converter which is quite simply an adapter.

# %% [markdown]
# [Media Converter.] It's hardware used to enable segments or networks using different media to interconnect and exchange signals. And this is a very cost-effective and flexible networking device. Now, in the graphic we see here, [A RJ-45 connector is attached to a UTP cable. The connector is directed to a Media convertor which is further directed to by two ST connectors that are connected to a Fiber cable. ] this is only one example of a media converter. There are several different types.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But, you can, for example, convert between unshielded twisted pair, with an RJ-45 connector to fiber and the appropriate ST connectors. So again, that's only one example. You might also see something like multi-mode fiber being converted to single-mode fiber and vice versa. But of course we can accept the electrical signals found on copper unshielded twisted pair, and convert them to light waves for fiber optic cabling.

# %% [markdown]
# Now, if you are talking about needing to convert hundreds of cable connections, you probably would not implement hundreds of converters. You would go with a larger scale, more robust, centralized device, capable of handling multiple conversions within that single device. But for just a few connections, a media converter can certainly do the job.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Application
# ***

# %% [markdown]
# Now, there can be other applications as well. This can be essential if the distance between two network devices is greater than the cable transmission distance.

# %% [markdown]
# For example, Ethernet still maxes out around a 100 meters. So if we need it to go beyond that, then we can use the converter because most of them also have the ability to boost the signal. In other words, they can act as repeaters. So this allows two network devices to connect across longer distances than if they were just using that single cable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocol Specific
# ***

# %% [markdown]
# Now typically, media converters are protocol specific, so you might need to be mindful of that. It supports various data rates and network types, but generally the protocol itself is specific to the converter. And they're usually implemented as physical layer devices, because they don't have really a lot of programming in them. But some of the higher scale converters do operate at layer 2, and provide some switching functionality as well. But that's what I was talking about in terms of if you needed a lot of conversions, you might go with a more robust converter. Something that can handle a number of connections and, in that case, it can also handle some of the switching that is required.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Other Characteristics
# ***

# %% [markdown]
# And finally, some other characteristics. Again, we know that they can help to expand the distance, [Conversion of UTP to fiber and Extension of fiber links.] and convert from different physical media types to other physical media types. But they can also implement WDM wavelength variances, which is wavelength division multiplexing.

# %% [markdown]
# This uses different colors, if you will, of laser to implement the multiplexing capability of the media, so that you can boost your performance over your present fiber links. Which might allow you to retain the investment that was made into that infrastructure a little bit longer rather than having to tear everything out and upgrade everything all at once. You can perhaps do a little bit of an incremental upgrade using simple media converters.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices9WirelessRangeExtenders"></a>
# ***
# ###### 9. Wireless Range Extenders
# ***

# %% [markdown]
# Now, this presentation will take a look at the wireless range extender. [Wireless Range Extender.] Which, as its name indicates, is used to extend the radio frequency range of wireless transmissions.

# %% [markdown]
# Now, it functions down at layer 1, the physical layer of the OSI model. And recall that in essence, there's not a whole lot of intelligence happening down at layer 1. There is really nothing more happening than hearing the signal on one side, boosting it, or what's also known as repeating it, and sending it along its way. So it allows you to extend the distance that can be covered of any given Ethernet network segment but, in this case, it's just done wirelessly.

# %% [markdown]
# So again, there's no intelligence happening here. It simply hears something coming in, boosts it, and sends it along its way. And then, of course, does the exact the same thing in reverse with respect to the devices that are communicating with it on the other side.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Distance
# ***

# %% [markdown]
# So in terms of the distance, it does depend on several factors, the transmission power of the access point itself and the gain of the antenna that is used. And, of course, the clients also are transmitters and receivers. So while this can certainly boost the range of the signal in terms of you being able to get farther away from the original router, but you still have to remain within a certain distance of the extender as well. Because, of course, your device has to transmit signals back to the extender. So your device does not get any more powerful because of the range extender. It simply allows you to get farther from the original access point or, in this case, the wireless router itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Connectivity
# ***

# %% [markdown]
# In terms of connectivity, it allows computers and other devices to connect to a wireless LAN generally outside of the wireless access point's normal range. So again, that is referring to the router itself. If that has a distance of X, then the extender can maybe go to 2X or 3X, depending on the power.

# %% [markdown]
# But that, again, only allows you to get a little farther away from the original router itself. You still have to be within range of the extender.

# %% [markdown]
# So for effective communication, of course, it requires that the transmitter be able to hear the receiver and the receiver be able to hear the transmitter. So an example of that is two-way radio communication. They both have to be within range of each other. So, again, not only is it a matter of the clients on the end being able to get farther away from the original access point, but the extender itself, of course, must also be within a reasonable range.

# %% [markdown]
# You don't want to place the extender at the very, very end of the range of the router itself. Because it just won't pick up on the signals strongly enough to be able to relay them. So you want a little bit of overlap, which you kind of see in the graphic there. The extender is well within the range of the router, then the devices remain well within the range of the extender. And I should also point out the fact that most of them are dual band. You can see the 5GHz and the 2.4GHz transmissions here. So a dual band extender is able to listen and/or communicate on both of those frequencies. So ultimately, it is just to allow your clients to get a little bit farther away from the original access point. But they still have to be within range of the extender itself for effective communications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevices10VoIPEndpoints"></a>
# ***
# ###### 10. VoIP Endpoints
# ***

# %% [markdown]
# In this presentation we will introduce Voice over Internet Protocol, or what is more commonly referred to as VoIP. [VoIP.] And this is a combination of hardware and software that are needed to make use of the Internet as a transmission medium for voice calls, hence the Voice over IP, which is the IP network of the Internet.

# %% [markdown]
# Now, with respect to an internal office organization, for example, you might already be familiar with a Voice over IP phone system, and that is exactly the same. It's just that you are using a LAN environment to transmit the calls as opposed to a WAN environment like the Internet. But in both cases, it is just a matter of taking voice data and packaging it up into data package that are sent using the Internet Protocol or IP. Instead of the standard method, if you will, of using the public switched telephone network or PSTN.

# %% [markdown]
# Now, that said, the PSTN is not going anywhere. You will certainly see a lot more VoIP systems implemented in the internal LAN environment. And it is certainly growing on the Internet as well. But with respect to using the Internet itself, particularly from the perspective of a personal user at home using their own computer. There are any number of applications that you can use to make voice calls over the Internet. And those are certainly fine. But they require the application to be installed on your system and on the system of the person on the other side. And you typically have to be signed into the application, both of you at the same time. And you have to configure each other, usually, as contacts.

# %% [markdown]
# So if I wanted to, for example, make a dentist appointment, I typically would not use that type of application. I would use, still, the standard public switched telephone network. So those types of more general public calls, if you will, certainly continue to rely on the PSTN. But for more personal calls to friends and family, you're certainly can use, again, any number of those types of applications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Costs
# ***

# %% [markdown]
# [VoIP — Benefits.] So this can offer several benefits including cost savings. You do not need the public switched telephone network to make the call. So particularly, if you are still paying any kind of long distance fee, well, there is no fee associated with a Voice over IP application above and beyond what you are paying for your Internet subscription.

# %% [markdown]
# So again, for those personal types of calls, you absolutely can just use the Internet at no additional cost.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Rich Media Services
# ***

# %% [markdown]
# Rich media services, there is integration with other protocols and applications. Particularly within the internal environment, you can have any number of applications that you might use to, for example, browse a corporate directory, looking for somebody within the organization. You might find them on an intranet webpage, and you can probably just click on their name to actually initiate a phone call.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Portability
# ***

# %% [markdown]
# Portability, phone numbers no longer require a dedicated line, you are using the IP network. And with respect to the Internet-based one is there is no geographical boundary. As long as you have Internet connectivity and you are a signed in into your service, you can make your calls.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Rich Features
# ***

# %% [markdown]
# Other rich features including click-to-call on a web page. Any given company, for example, might just place their number on the page as a hyperlink. And you can click on it, and that launches a call using your Voice over IP application.

# %% [markdown]
# And selective call forwarding, whereby you can configure which calls are forwarded. In traditional call forwarding, it was either on or off. All calls were forwarded or no calls were forwarded. But with selective, you can say if I get a call from person X, then forward it. But a call from person Y, just send it to voicemail.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VoIP Servers
# ***

# %% [markdown]
# [VoIP Servers.] Now VoIP servers are software based devices that are used to direct or participate in Voice over IP data conversations. For all intents and purposes, they are the operators. They have the characteristics of implementing call switching and connection management, call recording and auto-attendant functions. When you call any given business, for example, and you receive an automated attendant that says press one for so and so and two for so and so and three for this department or that location. Call conferencing and even translation if you are in a multilingual environment. So a lot of additional configuration and features that are available above and beyond traditional phone system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VoIP — Endpoints
# ***

# %% [markdown]
# [VoIP — Endpoints.] Now, the VoIP endpoints are typically the IP phones themselves. They are TCP/IP aware, they have an IP address. And they are connected directly to a data link using an RJ45 twisted pair Ethernet connection that can be plugged in directly to a hub or a switch. And they generally have a 10 or a 100BaseT auto-negotiating interface, so it can pick up on what speed is being used. But they are basically network devices like any other.

# %% [markdown]
# And you can also implement multiple endpoints, whereby you can assign several devices to ring upon receiving a phone call. This is particularly useful if you travel around from branch office to branch office to branch office. You can configure a call coming in to ring at all three offices, for example, so regardless of where you are, you receive that call.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Lot of Configuration
# ***

# %% [markdown]
# So again, a lot of configuration that you really just can't implement with standard phone systems. And a lot of integration with other types of applications are making Voice over IP much more commonly implemented.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practiceConfigureNetworkDevices"></a>
# ***
# ### Practice: Configure Network Devices
# ***

# %% [markdown]
# i. describe the difference between a host-based and a network-based firewall.
#
#
# ii. describe how switches and hubs work.
#
#
# iii. describe when to implement routers.
#
#
# iv. describe when to use a wireless range extender.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exerciseConfigureNetworkDevices"></a>
# ***
# ###### 1. Exercise: Configure Network Devices
# ***

# %% [markdown]
# i. And host-based firewalls are typically implemented as software running on a specific host and as such, they protect only that host. Whereas network-based firewalls are usually hardware appliances that sit between your network and the Internet. And as such, they protect the entire network. Now, it's certainly not a bad thing to have both of them. Because if the network-based is compromised, well then, you still have another layer of protection.

# %% [markdown]
# ii. Then we asked to describe how switches and hubs work. And beginning with hubs, these are layer 1 devices. So there's no addressing. Data coming in one port is copied out all other ports. So essentially, hubs are noisy. Switches, however, operate at layer 2. And as such, they understand MAC addresses. Data in one port is forwarded to only the specific port of the intended recipient system. They maintain tables. As packets goes through the switch from each device, it realizes that the MAC address that was attached to, for lack of a better word, this physical port, is computer one. And it does that for every system attached to every port. So that table is effectively maintained, so that each system can communicate with any other system without everyone else needing to hear it. So quite simply, switches are much quieter.

# %% [markdown]
# iii. Then we asked to describe when to implement routers. Now these are layer 3 devices. So they are not concerned with interconnecting two host systems, but rather two or more separate networks. They work at the logical address layer or the IP address. And they are only concerned with getting you from network to network to network, not any specific host on that network. And finally, we asked to describe when to use a wireless range extender.

# %% [markdown]
# iv. And this is required when devices needing to communicate with the originating access point are quite simply beyond the range of its transmission capabilities. Once you get to that limit, you implement the extender. It picks up on the original signals and, for all intents and purposes, boosts them. And as long as you remain within range of the extender, it can send the signals back to the originating access point. So again, it really is just a repeater, but for wireless networks. So hopefully you made out all right with those questions. And if so, we are ready to move on.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="typesofNetworkingDevicesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# # END JUPYTER NOTEBOOK
